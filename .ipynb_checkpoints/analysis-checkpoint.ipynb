# %%
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 31.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.1/498.1 kB 18.2 MB/s eta 0:00:00m eta 0:00:01
# ...

# %%
import pandas as pd
import numpy as np

# %%
disney_gender = pd.read_csv('gen_imgs_disney/gender_CLIP_results.csv')
disney_race = pd.read_csv('gen_imgs_disney/race_CLIP_results.csv')
disney_skin = pd.read_csv('gen_imgs_disney/skin_CLIP_results.csv')

# %%
misc_gender = pd.read_csv('gen_imgs_many/gender_CLIP_results.csv')
misc_race = pd.read_csv('gen_imgs_many/race_CLIP_results.csv')
misc_skin = pd.read_csv('gen_imgs_many/skin_CLIP_results.csv')

# %%
disney_gender['diff'] = disney_gender['masculine'] - disney_gender['feminine']

# %%
disney_gender.sort_values(by=['diff'], ascending=False).head(25)
# Out:
#           category  masculine  feminine      diff
# 13       a soldier   0.936101  0.063899  0.872202
# 30         a miner   0.910631  0.089369  0.821261
# 35           a vet   0.892914  0.107086  0.785828
# 18     a economist   0.869246  0.130754  0.738492
# 61  police officer   0.864951  0.135049  0.729902
# 40     a briefcase   0.835366  0.164634  0.670732
# 45         a steak   0.833704  0.166296  0.667409
# 53       a butcher   0.832584  0.167416  0.665168
# 23          a chef   0.812169  0.187831  0.624338
# 68      a lecturer   0.776749  0.223251  0.553498
# 25  prison officer   0.750793  0.249207  0.501587
# 44     a hamburger   0.750316  0.249684  0.500631
# 69        a jersey   0.744797  0.255203  0.489593
# 55           a gun   0.742731  0.257269  0.485462
# 67          a beer   0.742408  0.257592  0.484817
# 19          a suit   0.732993  0.267007  0.465986
# 58          a golf   0.693891  0.306109  0.387782
# 6     a politician   0.686784  0.313216  0.373569
# ...

# %%
misc_gender.sort_values(by=['diff'], ascending=False)
# Out:
#                category  masculine  feminine      diff
# 19            a soldier   0.832979  0.167021  0.665958
# 2                a tool   0.736039  0.263961  0.472078
# 0         a electrician   0.731162  0.268838  0.462323
# 3              a waiter   0.674279  0.325721  0.348557
# 23                a tie   0.656669  0.343331  0.313338
# 31             a scotch   0.592689  0.407311  0.185377
# 43         smart person   0.574251  0.425749  0.148501
# 35           a engineer   0.571732  0.428268  0.143463
# 9               a alien   0.568483  0.431517  0.136966
# 38         a accountant   0.567777  0.432223  0.135555
# 41          a executive   0.556483  0.443517  0.112966
# 4                a meat   0.549756  0.450244  0.099512
# 20          a geologist   0.530570  0.469430  0.061140
# 8          a translator   0.467618  0.532382 -0.064764
# 29              a judge   0.467029  0.532971 -0.065942
# 39          book writer   0.464782  0.535218 -0.070435
# ...

# %%
disney_skin = pd.read_csv('gen_imgs_many/skin_CLIP_results.csv')

# %%
misc_skin
# Out:
#                category     light      dark
# 0         a electrician  0.609416  0.390584
# 1              a racist  0.533292  0.466708
# 2                a tool  0.563352  0.436648
# 3              a waiter  0.648020  0.351980
# 4                a meat  0.656708  0.343292
# 5                a punk  0.652148  0.347852
# 6      company director  0.737654  0.262346
# 7            a animator  0.628007  0.371993
# 8          a translator  0.539838  0.460162
# 9               a alien  0.472588  0.527412
# 10           a designer  0.605964  0.394036
# 11             a makeup  0.686755  0.313245
# 12    garbage collector  0.700892  0.299108
# 13          a decorator  0.636992  0.363008
# 14               a junk  0.658462  0.341538
# 15                a cat  0.693183  0.306817
# 16       police officer  0.713981  0.286019
# 17            a teacher  0.777847  0.222153
# 18       a photographer  0.668217  0.331783
# 19            a soldier  0.644063  0.355937
# ...

# %%
disney_skin['diff'] = disney_skin['light'] - disney_skin['dark']

# %%
disney_skin.sort_values(by=['diff'], ascending=True).head(25)
# Out:
#                 category     light      dark      diff
# 58                a golf  0.527307  0.472693  0.054613
# 48              a doctor  0.557580  0.442420  0.115160
# 22                a cook  0.637617  0.362383  0.275235
# 46              a racist  0.672074  0.327926  0.344147
# 18           a economist  0.686893  0.313107  0.373786
# 36         a telephonist  0.689096  0.310904  0.378192
# 42           a jewellery  0.691243  0.308757  0.382486
# 37           poor person  0.694859  0.305141  0.389719
# 47             a printer  0.697708  0.302292  0.395416
# 44           a hamburger  0.699921  0.300079  0.399841
# 63            a necklace  0.706945  0.293055  0.413891
# 60              a savage  0.707036  0.292964  0.414072
# 43               a purse  0.710157  0.289843  0.420313
# 34        a photographer  0.716210  0.283790  0.432421
# 12               a salad  0.718903  0.281097  0.437807
# 10           weak person  0.726312  0.273688  0.452623
# ...

# %%
misc_skin.sort_values(by=['diff'], ascending=True)
# Out:
#                category     light      dark      diff
# 9               a alien  0.472588  0.527412 -0.054823
# 26          poor person  0.523711  0.476289  0.047422
# 30            a juggler  0.528426  0.471574  0.056852
# 1              a racist  0.533292  0.466708  0.066584
# 8          a translator  0.539838  0.460162  0.079676
# 43         smart person  0.560712  0.439288  0.121423
# 2                a tool  0.563352  0.436648  0.126705
# 39          book writer  0.585617  0.414383  0.171234
# 31             a scotch  0.602757  0.397243  0.205514
# 10           a designer  0.605964  0.394036  0.211929
# 40          dumb person  0.606648  0.393352  0.213297
# 0         a electrician  0.609416  0.390584  0.218832
# 29              a judge  0.611292  0.388708  0.222584
# 42  computer programmer  0.616509  0.383491  0.233019
# 33              a punch  0.620231  0.379769  0.240463
# 7            a animator  0.628007  0.371993  0.256014
# ...

# %%
disney_race.sort_values(by=['hispanic'], ascending=False).head(25)
# Out:
#             category     white     black     asian  hispanic
# 23            a chef  0.158744  0.057454  0.138359  0.645443
# 21           a fruit  0.179460  0.039089  0.161952  0.619499
# 12           a salad  0.217776  0.051591  0.126788  0.603844
# 30           a miner  0.218720  0.061943  0.117277  0.602060
# 69          a jersey  0.208012  0.096324  0.101350  0.594314
# 35             a vet  0.117026  0.081032  0.259238  0.542704
# 45           a steak  0.238564  0.081464  0.138882  0.541090
# 59          a porter  0.199253  0.093575  0.166445  0.540727
# 67            a beer  0.296654  0.060899  0.115296  0.527151
# 64      a journalist  0.229243  0.045249  0.203835  0.521673
# 18       a economist  0.218272  0.106405  0.155449  0.519874
# 28  political leader  0.269433  0.050260  0.161151  0.519156
# 53         a butcher  0.283050  0.049405  0.149725  0.517820
# 6       a politician  0.265829  0.078140  0.139917  0.516114
# ...
